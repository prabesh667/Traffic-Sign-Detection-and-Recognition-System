# %% [markdown]
# Yolov5 runs on top of pytorch and need to install tensorboard for visualization the performance of model

# %%
# !python -m pip install --upgrade pip

# !pip install tensorflow==2.3.1 

# !pip install tensorboard==2.4.1
# !pip install torch

# %% [markdown]
# Importing required libraries

# %%
import torch

# %%
from IPython.display import Image

# %%
#cloning to the yolov5 github page

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5

# %% [markdown]
# installing all the necessary libraries to run yolov5

# %%
# !pip install -r requirements.txt

# %%
#USE_GPU = X
import torch

# %%
# Print the installed PyTorch version
print(f'PyTorch version: {torch.__version__}\n')

# Print the name and the type of all GPU devices
print('Available GPU Devices:')

for i in range(torch.cuda.device_count()):

    print('  ', torch.cuda.get_device_name())

# %%
# Seting current CUDA device to USE_GPU
torch.cuda.set_device(USE_GPU)
use_cuda=torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

if use_cuda:

   print(f'\nUsing GPU device {torch.cuda.current_device()}')

# %%
--cfg models/yolov5x.yaml

# %% [markdown]
# Training yolov5 on custom data (rooad image of hamburg) to detect and classify taffic signs

# %%
# !python train.py --img 640 --batch 4 --epochs 50 --data coco128.yaml --weights yolov5l.pt  --hyp data/hyps/hyp.scratch.yaml --workers 2 --device 0
# Out:
# train: weights=yolov5l.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=50, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 35 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-155-gdc54ed5 torch 1.10.1+cu102 CUDA:0 (Quadro RTX 6000, 22696MiB)
#
# ...

# %%
# !python val.py --data coco128.yaml --img 640 --device 0 --workers 2 --weights runs/train/exp18/weights/best.pt --task speed --batch 32
# Out:
# val: data=/home/jovyan/yolov5/yolov5/yolov5/data/coco128.yaml, weights=['runs/train/exp18/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=speed, device=0, workers=2, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-155-gdc54ed5 torch 1.10.1+cu102 CUDA:0 (Quadro RTX 6000, 22696MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46210593 parameters, 0 gradients, 108.1 GFLOPs
# val: Scanning '/home/jovyan/yolov5/datasett/labels/val.cache' images and labels.
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         67        101      0.742        0.8      0.811      0.651
#  Dir_(Priority road)         67         11      0.907      0.818       0.88      0.677
#        Dir_(Parking)         67          6      0.857          1      0.876      0.633
# ...

# %%
# !python val.py --data coco128.yaml --img 640 --conf 0.001 --iou 0.65 --device 0  --weights runs/train/exp18/weights/best.pt
# Out:
# val: data=/home/jovyan/yolov5/yolov5/yolov5/data/coco128.yaml, weights=['runs/train/exp18/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-155-gdc54ed5 torch 1.10.1+cu102 CUDA:0 (Quadro RTX 6000, 22696MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46210593 parameters, 0 gradients, 108.1 GFLOPs
# val: Scanning '/home/jovyan/yolov5/datasett/labels/val.cache' images and labels.
#                Class     Images     Labels          P          R     mAP@.5 mAP@ERROR: Unexpected bus error encountered in worker. This might be caused by insufficient shared memory (shm).
# ERROR: Unexpected bus error encountered in worker. This might be caused by insufficient shared memory (shm).
# ...

# %% [markdown]
# Explore the metrics recorded during training using TensorBoard

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
Image(filename='runs/train/exp2/val_batch1_labels.jpg', width=1000)

# %%
Image(filename='runs/train/exp2/val_batch1_pred.jpg', width=1000)

# %%
#pip install opencv-python==4.5.3.56
# Out:
# ...
#      |████████████████████████████████| 49.9 MB 38.8 MB/s eta 0:00:01
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.4.0.44
#     Uninstalling opencv-python-4.4.0.44:
#       Successfully uninstalled opencv-python-4.4.0.44
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install qt5

# %% [markdown]
#  implementing the detect.py script with the best.pt weights and image dimensions of 614 pixels

# %%
# !python detect.py --source VID_20220125_123739.mp4 --weights runs/train/exp18/weights/best.pt --conf 0.50 --save-txt --save-conf
# Out:
# detect: weights=['runs/train/exp18/weights/best.pt'], source=VID_20220125_123739.mp4, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-155-gdc54ed5 torch 1.10.1+cu102 CUDA:0 (Quadro RTX 6000, 22696MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46210593 parameters, 0 gradients, 108.1 GFLOPs
# video 1/1 (1/2056) /home/jovyan/yolov5/yolov5/yolov5/VID_20220125_123739.mp4: 384x640 1 M_(No entry), Done. (0.015s)
# video 1/1 (2/2056) /home/jovyan/yolov5/yolov5/yolov5/VID_20220125_123739.mp4: 384x640 1 M_(No entry), Done. (0.013s)
# video 1/1 (3/2056) /home/jovyan/yolov5/yolov5/yolov5/VID_20220125_123739.mp4: 384x640 1 M_(No entry), Done. (0.013s)
# ...

# %%
#C:\Users\MSI\Desktop\Traffic_sign_detection\dataset\testdata
